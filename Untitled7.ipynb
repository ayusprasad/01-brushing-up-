# %% [markdown]
# <a href="https://colab.research.google.com/github/ayusprasad/01-brushing-up-/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %% [markdown]
# # custom data delimirters using sep peramenter

# %%
import pandas as pd
import numpy as np

exam_df=pd.read_csv("exam_review.csv",sep='>')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e5b633dbcf6b> in <cell line: 4>()
#       2 import numpy as np
#       3
# ----> 4 exam_df=pd.read_csv("exam_review.csv",sep='>')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# # **read SQL database**

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect('chinook.db')

# %%
# create a cursor
cur=conn.cursor()
cur.execute('SELECT * FROM EMPLOYEES ;')

# %%
result=cur.fetchall()

# %%
result
# Out:
# [(1,
#   'Adams',
#   'Andrew',
#   'General Manager',
#   None,
#   '1962-02-18 00:00:00',
#   '2002-08-14 00:00:00',
#   '11120 Jasper Ave NW',
#   'Edmonton',
#   'AB',
#   'Canada',
#   'T5K 2N1',
#   '+1 (780) 428-9482',
#   '+1 (780) 428-3457',
#   'andrew@chinookcorp.com'),
#  (2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com'),
#  (3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
# ...

# %%
df=pd.DataFrame(result)
df.head()
# Out:
#    0        1         2                    3    4                    5   \
# 0   1    Adams    Andrew      General Manager  NaN  1962-02-18 00:00:00
# 1   2  Edwards     Nancy        Sales Manager  1.0  1958-12-08 00:00:00
# 2   3  Peacock      Jane  Sales Support Agent  2.0  1973-08-29 00:00:00
# 3   4     Park  Margaret  Sales Support Agent  2.0  1947-09-19 00:00:00
# 4   5  Johnson     Steve  Sales Support Agent  2.0  1965-03-03 00:00:00
#
#                     6                    7         8   9       10       11  \
# 0  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton  AB  Canada  T5K 2N1
# 1  2002-05-01 00:00:00         825 8 Ave SW   Calgary  AB  Canada  T2P 2T3
# 2  2002-04-01 00:00:00        1111 6 Ave SW   Calgary  AB  Canada  T2P 5M5
# 3  2003-05-03 00:00:00     683 10 Street SW   Calgary  AB  Canada  T2P 5G3
# 4  2003-10-17 00:00:00         7727B 41 Ave   Calgary  AB  Canada  T3B 1Y7
#
#                   12                 13                        14
# ...

# %% [markdown]
# # **using pandas**

# %%
conn=sqlite3.connect('chinook.db')
df=pd.read_sql('SELECT * FROM EMPLOYEES',conn)
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeId  8 non-null      int64
#  1   LastName    8 non-null      object
#  2   FirstName   8 non-null      object
#  3   Title       8 non-null      object
#  4   ReportsTo   7 non-null      float64
#  5   BirthDate   8 non-null      object
#  6   HireDate    8 non-null      object
#  7   Address     8 non-null      object
#  8   City        8 non-null      object
#  9   State       8 non-null      object
#  10  Country     8 non-null      object
#  11  PostalCode  8 non-null      object
#  12  Phone       8 non-null      object
#  13  Fax         8 non-null      object
#  14  Email       8 non-null      object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 1.1+ KB

# %%
df.describe
# Out:
#        EmployeeId  ReportsTo
# count     8.00000   7.000000
# mean      4.50000   2.857143
# std       2.44949   2.193063
# min       1.00000   1.000000
# 25%       2.75000   1.500000
# 50%       4.50000   2.000000
# 75%       6.25000   4.000000
# max       8.00000   6.000000

# %% [markdown]
# # using query

# %%
from sqlalchemy import create_engine
engine=create_engine('sqlite:///chinook.db')
connection=engine.connect()
df=pd.read_sql_table('employees',con=connection)
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 2           3  Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 3           4     Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 4           5  Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2 2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3 2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4 2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# ...

# %% [markdown]
# # create table from database objects

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 2           3  Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 3           4     Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 4           5  Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2 2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3 2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4 2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# ...

# %%
cur=conn.cursor()
cur.execute('DROP TABLE IF EXISTS EMPLOYEE2;')
cur.close()
df.to_sql('employee2',conn)
pd.read_sql_query('SELECT * FROM EMPLOYEES2',conn).head()

# %% [markdown]
# html_url="https://www.basketball-reference.com/leagues/NBA_2019_per_game.html

# %%
html_url="https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# %%
nba_tables=pd.read_html(html_url)
nba=nba_tables[0]
nba.head()
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  DRB  \
# 0  1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2  1.4
# 1  2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3  2.2
# 2  3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3  1.4
# 3  4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9  4.6
# 4  5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0  5.3
#
#    TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %% [markdown]
# # **complex example from wikipedia**

# %%
import requests
import pandas as pd

html_url='https://en.wikipedia.org/wiki/Phineas_and_Ferb'
r=requests.get(html_url)
wiki_tables=pd.read_html(r.text,header=0)

# %%
phineas=wiki_tables[1]
phineas.head()
# Out:
#    Season  Segments  Episodes Episodes.1   Originally aired Originally aired.1
# 0  Season  Segments  Episodes   Episodes        First aired         Last aired
# 1       1        47        26         26    August 17, 2007  February 18, 2009
# 2       2        65        38         38  February 19, 2009  February 11, 2011
# 3       3        62        35         35      March 4, 2011  November 30, 2012
# 4       4        48        30         30   December 7, 2012      June 12, 2015

# %%
len(wiki_tables)
# Out:
# 16

# %%
phineas.drop(range(22,wiki_tables.shape[0]+1,20))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-353f366921d2> in <cell line: 1>()
# ----> 1 phineas.drop(range(22,wiki_tables.shape[0]+1,20))
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
phineas.drop([1,0],inplace=True)
phineas.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-e9282daa4a33> in <cell line: 1>()
# ----> 1 phineas.drop([1,0],inplace=True)
#       2 phineas.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
phineas.set_index('season',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-5b164b02b09e> in <cell line: 1>()
# ----> 1 phineas.set_index('season',inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['season'] are in the columns"

# %%
df=pd.read_excel('products.xlsx')
df.head()
# Out:
#              product_id   price  merchant_id      brand  \
# 0  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1  AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4  AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %%
pd.read_excel('products.xlsx').head()
# Out:
#              product_id   price  merchant_id      brand  \
# 0  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1  AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4  AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %%
pd.read_excel('products.xlsx',header=None).head()
# Out:
#                       0       1            2          3  \
# 0            product_id   price  merchant_id      brand
# 1  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 2  AVpgMuGwLJeJML43KY_c      69         1002    Boytone
# 3  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 4  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
#
#                                                    4
# 0                                               name
# 1  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 2  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 4  DreamWave - Tremor Portable Bluetooth Speaker ...

# %% [markdown]
# # excel file class

# %%
excel_file=pd.ExcelFile('products.xlsx')
excel_file

# %%
excel_file.sheet_names
# Out:
# ['Products', 'Descriptions', 'Merchants']

# %%
products=excel_file.parse('Products')

# %%
products.head()
# Out:
#              product_id   price  merchant_id      brand  \
# 0  AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1  AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2  AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3  AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4  AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
#
#                                                 name
# 0  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2           DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3  DreamWave - Tremor Portable Bluetooth Speaker ...
# 4  NS-SP1800BL 5.1-Channel Home Theater System (B...

# %% [markdown]
# # if the data is shifted in excel sheet

# %%
products.to_excel('out.xlsx',sheet_name='Products',startrow=1,startcol=2)

# %% [markdown]
# excel writer **use** **bold text**

# %%
writer=pd.ExcelWriter('out.xlsx')
writer

# %%
# pd.read_excel('out.xlsx',sheet_name='Products').head()

# %%
pd.read_excel('out.xlsx',sheet_name='Merchants').head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-f0c3f16b4474> in <cell line: 1>()
# ----> 1 pd.read_excel('out.xlsx',sheet_name='Merchants').head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
